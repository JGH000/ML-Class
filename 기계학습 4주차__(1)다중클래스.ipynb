# %%
from preamble import *
import mglearn
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

from sklearn.datasets import make_blobs

#3개의 클래스로 만들어서 실행해본다.
X, y = make_blobs(random_state = 42)

mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(["Class 0", "Class 1", "Class 2"])

# %%
from sklearn.linear_model import LogisticRegression

#LogisticRegression()에서 ()안에 multi_class을 따로 설정하지 않으면 multi_class 값은 auto로 설정이 된다.
# auto로 하게 되면 데이터가 binary이거나 solver가 liblinear이면 ovr로 선택이 되고
# 그렇지 않다면 multinomial이 선택이 된다. (지금 이 파일에선 auto를 쓸 경우에 multinomial로 선택이 된다.)
logr = LogisticRegression().fit(X, y)

print("계수 배열의 크기: ",logr.coef_.shape)
print("절편 배열의 크기: ",logr.intercept_.shape)

mglearn.plots.plot_2d_classification(logr, X, fill=True, alpha=.7)

mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)
for coef, intercept, color in zip(logr.coef_, logr.intercept_, mglearn.cm3.colors):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(['클래스 0', '클래스 1', '클래스 2', '클래스 0 경계', '클래스 1 경계', '클래스 2 경계'], loc=(1.01, 0.3))

print("계수 배열:\n", logr.coef_)
# Out:
# 계수 배열의 크기:  (3, 2)
# 절편 배열의 크기:  (3,)
# 계수 배열:
#  [[-0.385  0.629]
#  [ 0.741 -0.177]
#  [-0.356 -0.452]]

# %%
# multinomial를 사용하면 각 클래스에 대해서 loss를 계산하게 되서 전체 클래스에 대한 probability distribution을 계산하게 된다.
# 만약, solver가 liblinear이면 이용이 가능하지 않다
# 이걸 사용했을 때는 전체 결정 경계를 정확하게 나누게 된다.
logr = LogisticRegression(multi_class='multinomial').fit(X, y)

print("계수 배열의 크기: ",logr.coef_.shape)
print("절편 배열의 크기: ",logr.intercept_.shape)

mglearn.plots.plot_2d_classification(logr, X, fill=True, alpha=.7)

mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)
for coef, intercept, color in zip(logr.coef_, logr.intercept_, mglearn.cm3.colors):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(['클래스 0', '클래스 1', '클래스 2', '클래스 0 경계', '클래스 1 경계', '클래스 2 경계'], loc=(1.01, 0.3))

print("계수 배열:\n", logr.coef_)
# Out:
# 계수 배열의 크기:  (3, 2)
# 절편 배열의 크기:  (3,)
# 계수 배열:
#  [[-0.385  0.629]
#  [ 0.741 -0.177]
#  [-0.356 -0.452]]

# %%
# ovr을 사용하면 바이너리 문제로 풀게된다.
# 이걸 사용했을 때는 결정경계가 정확하게 나눠지지 않고 밑에 같이 중앙에 삼각형 같은 공간이 생기게 된다.
logr = LogisticRegression(multi_class='ovr').fit(X, y)

print("계수 배열의 크기: ",logr.coef_.shape)
print("절편 배열의 크기: ",logr.intercept_.shape)

mglearn.plots.plot_2d_classification(logr, X, fill=True, alpha=.7)

mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)
for coef, intercept, color in  zip(logr.coef_, logr.intercept_, mglearn.cm3.colors):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(['클래스 0', '클래스 1', '클래스 2', '클래스 0 경계', '클래스 1 경계', '클래스 2 경계'], loc=(1.01, 0.3))

print("계수 배열:\n", logr.coef_)
# Out:
# 계수 배열의 크기:  (3, 2)
# 절편 배열의 크기:  (3,)
# 계수 배열:
#  [[-0.683  1.062]
#  [ 1.365 -0.327]
#  [-0.612 -0.733]]

# %%
#위에서 했던 일련의 과정을 다시 해본다.
#대신 make_blobs()을 쓸 때 random_state값을 21로 해본다.
from preamble import *
import mglearn
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

from sklearn.datasets import make_blobs

#3개의 클래스로 만들어서 실행해본다.
X, y = make_blobs(random_state = 21)

mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(["Class 0", "Class 1", "Class 2"])

# %%
from sklearn.linear_model import LogisticRegression

#LogisticRegression()에서 ()안에 multi_class을 따로 설정하지 않으면 multi_class 값은 auto로 설정이 된다.
# auto로 하게 되면 데이터가 binary이거나 solver가 liblinear이면 ovr로 선택이 되고
# 그렇지 않다면 multinomial이 선택이 된다.
logr = LogisticRegression().fit(X, y)

print("계수 배열의 크기: ",logr.coef_.shape)
print("절편 배열의 크기: ",logr.intercept_.shape)

mglearn.plots.plot_2d_classification(logr, X, fill=True, alpha=.7)

mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)
for coef, intercept, color in zip(logr.coef_, logr.intercept_, mglearn.cm3.colors):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(['클래스 0', '클래스 1', '클래스 2', '클래스 0 경계', '클래스 1 경계', '클래스 2 경계'], loc=(1.01, 0.3))

print("계수 배열:\n", logr.coef_)
# Out:
# 계수 배열의 크기:  (3, 2)
# 절편 배열의 크기:  (3,)
# 계수 배열:
#  [[-1.111  1.002]
#  [ 1.207 -0.271]
#  [-0.096 -0.731]]

# %%
# multinomial를 사용하면 각 클래스에 대해서 loss를 계산하게 되서 전체 클래스에 대한 probability distribution을 계산하게 된다.
# 만약, solver가 liblinear이면 이용이 가능하지 않다
# 이걸 사용했을 때는 전체 결정 경계를 정확하게 나누게 된다.
logr = LogisticRegression(multi_class='multinomial').fit(X, y)

print("계수 배열의 크기: ",logr.coef_.shape)
print("절편 배열의 크기: ",logr.intercept_.shape)

mglearn.plots.plot_2d_classification(logr, X, fill=True, alpha=.7)

mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)
for coef, intercept, color in zip(logr.coef_, logr.intercept_, mglearn.cm3.colors):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(['클래스 0', '클래스 1', '클래스 2', '클래스 0 경계', '클래스 1 경계', '클래스 2 경계'], loc=(1.01, 0.3))

print("계수 배열:\n", logr.coef_)
# Out:
# 계수 배열의 크기:  (3, 2)
# 절편 배열의 크기:  (3,)
# 계수 배열:
#  [[-1.111  1.002]
#  [ 1.207 -0.271]
#  [-0.096 -0.731]]

# %%
# ovr을 사용하면 바이너리 문제로 풀게된다.
# 이걸 사용했을 때는 결정경계가 정확하게 나눠지지 않고 밑에 같이 중앙에 삼각형 같은 공간이 생기게 된다.
logr = LogisticRegression(multi_class='ovr').fit(X, y)

print("계수 배열의 크기: ",logr.coef_.shape)
print("절편 배열의 크기: ",logr.intercept_.shape)

mglearn.plots.plot_2d_classification(logr, X, fill=True, alpha=.7)

mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)
for coef, intercept, color in  zip(logr.coef_, logr.intercept_, mglearn.cm3.colors):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(['클래스 0', '클래스 1', '클래스 2', '클래스 0 경계', '클래스 1 경계', '클래스 2 경계'], loc=(1.01, 0.3))

print("계수 배열:\n", logr.coef_)

#이번사례는 보면 클래스2에 해당되는 거 하나가 경계를 벗어나는 것을 볼 수 있다.
# Out:
# 계수 배열의 크기:  (3, 2)
# 절편 배열의 크기:  (3,)
# 계수 배열:
#  [[-1.112  1.492]
#  [ 1.234 -0.065]
#  [-0.868 -2.002]]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris_dataset = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state=0, test_size=0.40)
logr = LogisticRegression().fit(X, y) #
logr.fit(X_train, y_train)
y_pred = logr.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

print("테스트 세트의 정확도: {:.2f}".format(logr.score(X_test, y_test)))
print("Number of mislabeled points out of a total %d points : %d", (X_test.shape[0],(y_test != y_pred).sum()))

print("predict:\n", logr.predict(X_test[:5]))
print("probability:\n", logr.predict_proba(X_test[:5]))
# Out:
# [[16  0  0]
#  [ 0 22  1]
#  [ 0  4 17]]
# 테스트 세트의 정확도: 0.92
# Number of mislabeled points out of a total %d points : %d (60, 5)
# predict:
#  [2 1 0 2 0]
# probability:
#  [[0.    0.123 0.877]
#  [0.015 0.968 0.017]
#  [0.987 0.013 0.   ]
#  [0.    0.041 0.959]
#  [0.971 0.029 0.   ]]

# %%
logr = LogisticRegression(multi_class='multinomial').fit(X, y)
logr.fit(X_train, y_train)
y_pred = logr.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

print("\테스트 세트의 정확도: {:.2f}".format(logr.score(X_test, y_test)))
print("Number of mislabeled points out of a total %d points : %d", (X_test.shape[0],(y_test != y_pred).sum()))

print("predict:\n", logr.predict(X_test[:5]))
print("probability:\n", logr.predict_proba(X_test[:5]))
# Out:
# [[16  0  0]
#  [ 0 22  1]
#  [ 0  4 17]]
# \테스트 세트의 정확도: 0.92
# Number of mislabeled points out of a total %d points : %d (60, 5)
# predict:
#  [2 1 0 2 0]
# probability:
#  [[0.    0.123 0.877]
#  [0.015 0.968 0.017]
#  [0.987 0.013 0.   ]
#  [0.    0.041 0.959]
#  [0.971 0.029 0.   ]]

# %%
logr = LogisticRegression(multi_class='ovr').fit(X, y)
logr.fit(X_train, y_train)
y_pred = logr.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

print("\테스트 세트의 정확도: {:.2f}".format(logr.score(X_test, y_test)))
print("Number of mislabeled points out of a total %d points : %d", (X_test.shape[0],(y_test != y_pred).sum()))

print("predict:\n", logr.predict(X_test[:5]))
print("probability:\n", logr.predict_proba(X_test[:5]))
# Out:
# [[16  0  0]
#  [ 0 20  3]
#  [ 0  3 18]]
# \테스트 세트의 정확도: 0.90
# Number of mislabeled points out of a total %d points : %d (60, 6)
# predict:
#  [2 1 0 2 0]
# probability:
#  [[0.001 0.313 0.687]
#  [0.029 0.937 0.034]
#  [0.981 0.019 0.   ]
#  [0.    0.333 0.667]
#  [0.89  0.11  0.   ]]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris_dataset = load_iris()
#위에서 했던 것을 다시 반복해보는데 대신 test_size를 0.50으로 해본다.
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state=0, test_size=0.50)
logr = LogisticRegression().fit(X, y)
logr.fit(X_train, y_train)
y_pred = logr.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

print("테스트 세트의 정확도: {:.2f}".format(logr.score(X_test, y_test)))
print("Number of mislabeled points out of a total %d points : %d", (X_test.shape[0],(y_test != y_pred).sum()))

print("predict:\n", logr.predict(X_test[:5]))
print("probability:\n", logr.predict_proba(X_test[:5]))
# Out:
# [[21  0  0]
#  [ 0 29  1]
#  [ 0  4 20]]
# 테스트 세트의 정확도: 0.93
# Number of mislabeled points out of a total %d points : %d (75, 5)
# predict:
#  [2 1 0 2 0]
# probability:
#  [[0.001 0.147 0.852]
#  [0.018 0.96  0.021]
#  [0.988 0.012 0.   ]
#  [0.    0.049 0.951]
#  [0.969 0.031 0.   ]]

# %%
logr = LogisticRegression(multi_class='multinomial').fit(X, y)
logr.fit(X_train, y_train)
y_pred = logr.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

print("\테스트 세트의 정확도: {:.2f}".format(logr.score(X_test, y_test)))
print("Number of mislabeled points out of a total %d points : %d", (X_test.shape[0],(y_test != y_pred).sum()))

print("predict:\n", logr.predict(X_test[:5]))
print("probability:\n", logr.predict_proba(X_test[:5]))
# Out:
# [[21  0  0]
#  [ 0 29  1]
#  [ 0  4 20]]
# \테스트 세트의 정확도: 0.93
# Number of mislabeled points out of a total %d points : %d (75, 5)
# predict:
#  [2 1 0 2 0]
# probability:
#  [[0.001 0.147 0.852]
#  [0.018 0.96  0.021]
#  [0.988 0.012 0.   ]
#  [0.    0.049 0.951]
#  [0.969 0.031 0.   ]]

# %%
logr = LogisticRegression(multi_class='ovr').fit(X, y)
logr.fit(X_train, y_train)
y_pred = logr.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

print("\테스트 세트의 정확도: {:.2f}".format(logr.score(X_test, y_test)))
print("Number of mislabeled points out of a total %d points : %d", (X_test.shape[0],(y_test != y_pred).sum()))

print("predict:\n", logr.predict(X_test[:5]))
print("probability:\n", logr.predict_proba(X_test[:5]))

#test_size를 0.50으로 했을 때는 multinomial를 사용할 때의 정확도는 증가했지만
# ovr를 사용했을 때의 정확도는 감소했다는 것을 볼 수 있다.
# Out:
# [[21  0  0]
#  [ 0 23  7]
#  [ 0  2 22]]
# \테스트 세트의 정확도: 0.88
# Number of mislabeled points out of a total %d points : %d (75, 9)
# predict:
#  [2 1 0 2 0]
# probability:
#  [[0.001 0.29  0.708]
#  [0.035 0.92  0.045]
#  [0.985 0.015 0.   ]
#  [0.    0.303 0.697]
#  [0.902 0.097 0.   ]]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris_dataset = load_iris()
#위에서 했던 것을 다시 반복해보는데 대신 test_size를 0.20으로 해본다.
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state=0, test_size=0.38)
logr = LogisticRegression().fit(X, y)
logr.fit(X_train, y_train)
y_pred = logr.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

print("테스트 세트의 정확도: {:.2f}".format(logr.score(X_test, y_test)))
print("Number of mislabeled points out of a total %d points : %d", (X_test.shape[0],(y_test != y_pred).sum()))

print("predict:\n", logr.predict(X_test[:5]))
print("probability:\n", logr.predict_proba(X_test[:5]))
# Out:
# [[16  0  0]
#  [ 0 21  1]
#  [ 0  4 15]]
# 테스트 세트의 정확도: 0.91
# Number of mislabeled points out of a total %d points : %d (57, 5)
# predict:
#  [2 1 0 2 0]
# probability:
#  [[0.    0.097 0.903]
#  [0.015 0.967 0.018]
#  [0.986 0.014 0.   ]
#  [0.    0.038 0.962]
#  [0.97  0.03  0.   ]]

# %%
logr = LogisticRegression(multi_class='multinomial').fit(X, y)
logr.fit(X_train, y_train)
y_pred = logr.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

print("\테스트 세트의 정확도: {:.2f}".format(logr.score(X_test, y_test)))
print("Number of mislabeled points out of a total %d points : %d", (X_test.shape[0],(y_test != y_pred).sum()))

print("predict:\n", logr.predict(X_test[:5]))
print("probability:\n", logr.predict_proba(X_test[:5]))
# Out:
# [[16  0  0]
#  [ 0 21  1]
#  [ 0  4 15]]
# \테스트 세트의 정확도: 0.91
# Number of mislabeled points out of a total %d points : %d (57, 5)
# predict:
#  [2 1 0 2 0]
# probability:
#  [[0.    0.097 0.903]
#  [0.015 0.967 0.018]
#  [0.986 0.014 0.   ]
#  [0.    0.038 0.962]
#  [0.97  0.03  0.   ]]

# %%
logr = LogisticRegression(multi_class='ovr').fit(X, y)
logr.fit(X_train, y_train)
y_pred = logr.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

print("\테스트 세트의 정확도: {:.2f}".format(logr.score(X_test, y_test)))
print("Number of mislabeled points out of a total %d points : %d", (X_test.shape[0],(y_test != y_pred).sum()))

print("predict:\n", logr.predict(X_test[:5]))
print("probability:\n", logr.predict_proba(X_test[:5]))

#test_size를 0.38으로 했을 때는 multinomial를 사용할 때의 정확도는 감소했지만
# ovr를 사용했을 때의 정확도는 증가했다는 것을 볼 수 있다.
# Out:
# [[16  0  0]
#  [ 0 19  3]
#  [ 0  2 17]]
# \테스트 세트의 정확도: 0.91
# Number of mislabeled points out of a total %d points : %d (57, 5)
# predict:
#  [2 1 0 2 0]
# probability:
#  [[0.001 0.276 0.723]
#  [0.029 0.936 0.036]
#  [0.976 0.024 0.   ]
#  [0.    0.344 0.656]
#  [0.882 0.118 0.   ]]
